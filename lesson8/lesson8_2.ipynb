# %%
#請建立一個範本list
my_list = [1, 2, 3, 4, 5]
print(type(my_list))
my_list.append(6)
print(my_list)

# %%
#請建立一個範本list
my_list = [1, 2, 3, 4, 5]
#並且建立常用的實體方法
my_list.append(6)
print(my_list)
my_list.remove(2)
print(my_list)
my_list.insert(1, 10)
print(my_list)
my_list.sort()
print(my_list)
my_list.reverse()
print(my_list)
my_list.clear()
print(my_list)
